# %%
 import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#Preprocessing phase
data = pd.read_csv('titanic-passengers.csv',sep=";")

# %%
data.shape
# Out:
# (891, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
#finding_the_missing_value
import pandas as pd
df = pd.DataFrame(data)
df.isnull()
#returns True if a field has missing values and false if the field does not have missing values.
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False   True  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False   True     False
# 4    False  False     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False   True     False
# 888  False   True     False
# 889  False   True     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
#Number of the missing values on each column
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Number of missing values in the DataFrame
df.isnull().sum().sum()
# Out:
# 866

# %%
#Dropping missing values
data.dropna(axis=1, how='any', thresh=None, inplace=False)
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                           Collander, Mr. Erik Gustaf    male      0      0
# 1                              Moen, Mr. Sigurd Hansen    male      0      0
# 2                               Jensen, Mr. Hans Peder    male      0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female      0      4
# 4                               Davidson, Mr. Thornton    male      1      0
# ..                                                 ...     ...    ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female      1      0
# 887                              Sirayanian, Mr. Orsen    male      0      0
# 888                                Cacic, Miss. Marija  female      0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male      0      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female      0      0
#
#          Ticket     Fare
# 0        248740  13.0000
# 1        348123   7.6500
# 2        350050   7.8542
# 3        349909  21.0750
# 4    F.C. 12750  52.0000
# ..          ...      ...
# 886      237736  30.0708
# 887        2669   7.2292
# 888      315084   8.6625
# 889      349215   7.8958
# 890      250655  26.0000
#
# [891 rows x 9 columns]

# %%
#Replace the numerical missing Value (Age)
data['Age'].fillna(data['Age'].mean(), inplace=True)
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
#Replace the categorical missing values 
Type= len(data["Cabin"])
print("Type :", Type)
print(data["Cabin"].value_counts())
data["Cabin"].fillna("G", inplace=True)
data.tail()
# Out:
# Type : 891
# G6             4
# B96 B98        4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# D46            1
# A14            1
# C70            1
# B94            1
# B3             1
# Name: Cabin, Length: 147, dtype: int64
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 886      1      0  237736  30.0708     G        C
# 887      0      0    2669   7.2292     G        C
# 888      0      0  315084   8.6625     G        S
# 889      0      0  349215   7.8958     G        S
# 890      0      0  250655  26.0000     G        S

# %%
#Verify if the data is ready to be treated
data.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000      G        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542      G        S
# 3  female  29.0      0      4      349909  21.0750      G        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
#Visualization phase
import os 
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
#Distribution
#Variable distribution describes in a graphical format how often the values of the variable occurs in the dataset.
# histograms, barplots, and boxplots.
plt.title("Histogram of different ages")
plt.xlabel("Age")
data["Age"].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of different ages'}, xlabel='Age', ylabel='Frequency'>

# %%
#Visualize the correlation between Pclass and Survived 
g=sns.FacetGrid(data,col="Survived")
g.map(plt.hist,'Pclass',bins=20)

# %%
#Visualize the correlation between Embarked Tow and Price of the ticket
g=sns.FacetGrid(data,col="Embarked")
g.map(plt.hist,'Ticket',bins=20)

# %%
#Paragraph:
#This function will create the correlations between the features that we have in our dataset.
#it will therefore make us visualize through s = sns.heatmap () the relationship between the different features of our dataset.
#for example 'Parch' and 'SibPc' have a very close correlation because they are equal to 1.
#in other words, the more the correlation results are equal to one, the more the variables are correlated and linked.
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(df)

# %%
#Use the groupby function combined with the mean() to view the relation between Pclass and survived 
data[['Pclass', 'Survived']].groupby(['Survived'], as_index = False)['Pclass'].mean()
# Out:
#   Survived    Pclass
# 0       No  2.531876
# 1      Yes  1.950292

# %%
#as a final step try to drop the useless columns such as Name
data.drop(["Name"],axis=1,inplace=True)
data.head()
# Out:
#    PassengerId Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# 0          343       No       2    male  28.0      0      0      248740
# 1           76       No       3    male  25.0      0      0      348123
# 2          641       No       3    male  20.0      0      0      350050
# 3          568       No       3  female  29.0      0      4      349909
# 4          672       No       1    male  31.0      1      0  F.C. 12750
#
#       Fare  Cabin Embarked
# 0  13.0000      G        S
# 1   7.6500  F G73        S
# 2   7.8542      G        S
# 3  21.0750      G        S
# 4  52.0000    B71        S

# %%
#as a final step try to drop the useless columns such as SibSp
data.drop(["SibSp"],axis=1,inplace=True)
data.head()
# Out:
#    PassengerId Survived  Pclass     Sex   Age  Parch      Ticket     Fare  \
# 0          343       No       2    male  28.0      0      248740  13.0000
# 1           76       No       3    male  25.0      0      348123   7.6500
# 2          641       No       3    male  20.0      0      350050   7.8542
# 3          568       No       3  female  29.0      4      349909  21.0750
# 4          672       No       1    male  31.0      0  F.C. 12750  52.0000
#
#    Cabin Embarked
# 0      G        S
# 1  F G73        S
# 2      G        S
# 3      G        S
# 4    B71        S

# %%
#as a final step try to drop the useless columns such as Parch
data.drop(['Parch'],axis=1,inplace=True)
data.head()
# Out:
#    PassengerId Survived  Pclass     Sex   Age      Ticket     Fare  Cabin  \
# 0          343       No       2    male  28.0      248740  13.0000      G
# 1           76       No       3    male  25.0      348123   7.6500  F G73
# 2          641       No       3    male  20.0      350050   7.8542      G
# 3          568       No       3  female  29.0      349909  21.0750      G
# 4          672       No       1    male  31.0  F.C. 12750  52.0000    B71
#
#   Embarked
# 0        S
# 1        S
# 2        S
# 3        S
# 4        S

# %%
#Create a new column called Title which contains the appropriate Title for each individual
df['Title'] = df['Name'].str.extract(r', (\w+\.)')
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked Title
# 0    male  28.0      0      0      248740  13.0000      G        S   Mr.
# 1    male  25.0      0      0      348123   7.6500  F G73        S   Mr.
# 2    male  20.0      0      0      350050   7.8542      G        S   Mr.
# 3  female  29.0      0      4      349909  21.0750      G        S  Mrs.
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S   Mr.

# %%
#Visualize the correlation between Title and other features(e.g Sex, Fare, Age...)
g= sns.FacetGrid(df, col="Title")
g.map(sns.barplot,'Age', alpha=.5)
g.add_legend()
# Out:
# C:\Users\Ismail OTSMANE\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#Visualize the correlation between Title and other features(e.g Sex, Fare, Age...)
df.info()
df["Title"].values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     889 non-null    object
#  12  Title        890 non-null    object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 90.6+ KB
# array(['Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mr.',
#        'Mrs.', 'Mr.', 'Miss.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.',
#        'Dr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Major.', 'Mrs.',
#        'Don.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Miss.', 'Mr.', 'Mr.',
#        'Miss.', 'Mr.', 'Miss.', 'Mr.', 'Master.', 'Dr.', 'Mr.', 'Mr.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Mrs.', 'Mrs.', 'Miss.', 'Miss.', 'Master.', 'Miss.', 'Mr.',
#        'Rev.', 'Mr.', 'Mrs.', 'Mrs.', 'Miss.', 'Mr.', 'Mrs.', 'Mr.',
#        'Mr.', 'Miss.', 'Mr.', 'Miss.', 'Miss.', 'Miss.', 'Mrs.',
#        'Master.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.',
#        'Mrs.', 'Mrs.', 'Miss.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Miss.',
#        'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Master.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Mrs.', 'Miss.', 'Mr.', 'Mr.', 'Master.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Col.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mr.',
#        'Mr.', 'Miss.', 'Mr.', 'Mrs.', 'Miss.', 'Mr.', 'Miss.', 'Mrs.',
#        'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Miss.', 'Mrs.',
#        'Mr.', 'Miss.', 'Mr.', 'Mrs.', 'Miss.', 'Mr.', 'Mr.', 'Mr.',
#        'Miss.', 'Master.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mrs.', 'Miss.',
#        'Master.', 'Miss.', 'Mr.', 'Miss.', 'Mrs.', 'Mr.', 'Mr.', 'Dr.',
#        'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.',
#        'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Master.', 'Mr.',
#        'Mrs.', 'Miss.', 'Mrs.', 'Miss.', 'Miss.', 'Mr.', 'Miss.', 'Mr.',
#        'Mr.', 'Mrs.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.',
#        'Miss.', 'Mr.', 'Mrs.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Master.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mrs.', 'Miss.', 'Mr.',
#        'Mrs.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Miss.', 'Miss.', 'Mrs.',
#        'Mr.', 'Master.', 'Mlle.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.',
#        'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Miss.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Miss.', 'Mrs.', 'Mr.',
#        'Master.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Dr.', 'Mr.', 'Mrs.', 'Miss.', 'Mr.', 'Mr.', 'Mrs.', 'Miss.',
#        'Mrs.', 'Mr.', 'Miss.', 'Mr.', 'Miss.', 'Miss.', 'Mrs.', 'Mrs.',
#        'Mrs.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Miss.', 'Mrs.',
#        'Mrs.', 'Master.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Miss.', 'Mr.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mrs.', 'Mr.', 'Mr.', 'Miss.',
#        'Mr.', 'Mrs.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.',
#        'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Miss.', 'Miss.', 'Mr.',
#        'Mrs.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.',
#        'Mr.', 'Miss.', 'Miss.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Miss.',
#        'Mr.', 'Master.', 'Mrs.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Miss.',
#        'Mrs.', 'Miss.', 'Mr.', 'Miss.', 'Miss.', 'Mr.', 'Miss.', 'Miss.',
#        'Mr.', 'Miss.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Miss.',
#        'Mr.', 'Master.', 'Mr.', 'Miss.', 'Miss.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Lady.',
#        'Miss.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Miss.', 'Master.', 'Mrs.', 'Mrs.', 'Master.', 'Mrs.',
#        'Miss.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Dr.', 'Dr.',
#        'Mrs.', 'Mr.', 'Master.', 'Mr.', 'Miss.', 'Mr.', 'Master.', 'Mrs.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Miss.', 'Mr.',
#        'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mlle.', 'Miss.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Master.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mrs.', 'Mr.',
#        'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.',
#        'Mr.', 'Miss.', 'Miss.', 'Master.', 'Mr.', 'Mrs.', 'Mrs.', 'Mr.',
#        'Miss.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mrs.', 'Mr.', 'Miss.',
#        'Miss.', 'Mrs.', 'Mr.', 'Miss.', 'Mr.', 'Mrs.', 'Miss.', 'Mr.',
#        'Miss.', 'Miss.', 'Miss.', 'Mr.', 'Mrs.', 'Mr.', 'Miss.', 'Miss.',
#        'Mr.', 'Miss.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.',
#        'Miss.', 'Mr.', 'Master.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.',
#        'Mr.', 'Master.', 'Miss.', 'Mrs.', 'Mr.', 'Jonkheer.', 'Mr.',
#        'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Miss.', 'Mr.', 'Mrs.', 'Mr.', 'Miss.', 'Master.', 'Mrs.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.',
#        'Master.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mr.',
#        'Miss.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Master.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Miss.', 'Miss.', 'Miss.', 'Miss.', 'Mr.', 'Mr.', 'Mr.',
#        'Mrs.', 'Master.', 'Mr.', 'Master.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mrs.', 'Mr.', 'Master.', 'Mr.',
#        'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mme.', 'Miss.', 'Mr.',
#        'Miss.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.',
#        'Miss.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Master.', 'Mrs.',
#        'Master.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Master.', 'Mrs.', 'Mr.', 'Miss.',
#        'Mr.', 'Mr.', 'Miss.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.',
#        'Miss.', 'Mr.', 'Mr.', 'Sir.', 'Mr.', 'Mr.', 'Miss.', 'Miss.',
#        'Mr.', 'Miss.', 'Mrs.', 'Mr.', 'Mrs.', 'Miss.', 'Mr.', 'Mr.',
#        'Miss.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Miss.', 'Miss.', 'Mr.',
#        'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Mr.',
#        'Capt.', 'Mrs.', 'Mr.', 'Mrs.', 'Mrs.', 'Mr.', 'Master.', 'Mr.',
#        'Mrs.', 'Mrs.', 'Mrs.', 'Major.', 'Mr.', 'Master.', 'Mr.', 'Mr.',
#        'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Rev.', 'Mr.', 'Mr.', 'Mr.',
#        'Master.', 'Mr.', 'Rev.', 'Miss.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.',
#        'Mr.', 'Miss.', 'Dr.', 'Mr.', 'Mrs.', 'Mr.', 'Mrs.', 'Mr.',
#        'Miss.', 'Mr.', 'Mrs.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.',
#        'Mrs.', 'Mrs.', 'Col.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.',
#        'Rev.', 'Mr.', 'Mr.', 'Mrs.', 'Rev.', 'Miss.', 'Miss.', 'Mr.', nan,
#        'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Miss.',
#        'Master.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Miss.', 'Miss.', 'Mr.',
#        'Mr.', 'Miss.', 'Mr.', 'Mrs.', 'Mr.', 'Miss.', 'Mrs.', 'Miss.',
#        'Mr.', 'Miss.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.',
#        'Miss.', 'Mr.', 'Miss.', 'Miss.', 'Mrs.', 'Mr.', 'Miss.', 'Mrs.',
#        'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Miss.',
#        'Master.', 'Master.', 'Mr.', 'Master.', 'Mr.', 'Miss.', 'Miss.',
#        'Mrs.', 'Mr.', 'Mrs.', 'Mr.', 'Mrs.', 'Miss.', 'Miss.', 'Ms.',
#        'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.',
#        'Miss.', 'Miss.', 'Miss.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.',
#        'Miss.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mrs.', 'Miss.', 'Mr.',
#        'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Master.', 'Mrs.', 'Miss.', 'Mr.', 'Miss.', 'Mr.', 'Miss.',
#        'Mr.', 'Mr.', 'Miss.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.',
#        'Mr.', 'Mr.', 'Master.', 'Mr.', 'Miss.', 'Mr.', 'Miss.', 'Miss.',
#        'Miss.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Rev.', 'Mrs.', 'Mr.',
#        'Miss.', 'Mr.', 'Miss.'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df["Sex"]= encoder.fit_transform(df["Sex"])
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked Title
# 0    1  28.0      0      0      248740  13.0000      G        S   Mr.
# 1    1  25.0      0      0      348123   7.6500  F G73        S   Mr.
# 2    1  20.0      0      0      350050   7.8542      G        S   Mr.
# 3    0  29.0      0      4      349909  21.0750      G        S  Mrs.
# 4    1  31.0      1      0  F.C. 12750  52.0000    B71        S   Mr.

# %%
grid = sns.FacetGrid(df,col='Title', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex', 'Fare','Age', alpha=.5, ci=None)
grid.add_legend()
# Out:
# C:\Users\Ismail OTSMANE\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Ismail OTSMANE\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# C:\Users\Ismail OTSMANE\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:675: UserWarning: Using the barplot function without specifying `hue_order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
 data['Title'] = data['Title'].replace=  {
 
                    "Capt":       "Officer",
 
                    "Col":        "Officer",
 
                    "Major":      "Officer",
 
                      "Dr":         "Officer",
 
                    "Rev":        "Officer","Jonkheer":   "Royalty",
 
                    "Don":        "Royalty",
 
                    "Sir" :       "Royalty",
 
                   "Lady" :      "Royalty",
 
                  "the Countess": "Royalty",
 
                    "Dona":       "Royalty", "Mme":        "Miss",
 
                    "Mlle":       "Miss",
 
                    "Miss" :      "Miss",
 
                    "Ms":         "Mrs",
 
                    "Mr" :        "Mrs",
 
                    "Mrs" :       "Mrs",
 
                    "Master" :    "Master"}
data.replace(To, inplace= True)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ISMAIL~1\AppData\Local\Temp/ipykernel_6764/3466212461.py in <module>
# ----> 1 data['Title'] = data['Title'].replace=  {
#       2
#       3                    "Capt":       "Officer",
#       4
#       5                    "Col":        "Officer",
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# -> 3899             value = sanitize_index(value, self.index)
#    3900             if not isinstance(value, (np.ndarray, Index)):
#    3901                 if isinstance(value, list) and len(value) > 0:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     749     """
#     750     if len(data) != len(index):
# --> 751         raise ValueError(
#     752             "Length of values "
#     753             f"({len(data)}) "
#
# ValueError: Length of values (18) does not match length of index (891)

# %%
#Yes FamilySize is useful because it represents the correlation between the two 
#features Parch and Size which gives us a lot of information about our dataset.
data = data.assign(familySize = (data["SibSp"] + data["Parch"] + 1))
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SibSp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\ISMAIL~1\AppData\Local\Temp/ipykernel_6764/2582872881.py in <module>
#       1 #Yes FamilySize is useful because it represents the correlation between the two
#       2 #features Parch and Size which gives us a lot of information about our dataset.
# ----> 3 data = data.assign(familySize = (data["SibSp"] + data["Parch"] + 1))
#       4 data
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'SibSp'
